# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os 
from pathlib import Path

import pandas as pd
from src.data.tsf_loader import convert_tsf_to_dataframe
DATA_DIR = Path(os.getcwd()).parent / "data"

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## M4 Daily Dataset
# Downloaded from [here](https://zenodo.org/records/4656548) courtesy of https://forecastingdata.org/

# %%
(df, frequency, forecast_horizon, contain_missing_values, contain_equal_length) = convert_tsf_to_dataframe(DATA_DIR / "m4_daily_dataset.tsf")

# %%
df.head()
# Out:
#   series_name     start_timestamp  \
# 0          T1 1994-01-03 12:00:00
# 1          T2 1995-01-02 12:00:00
# 2          T3 2006-01-05 12:00:00
# 3          T4 1996-05-30 12:00:00
# 4          T5 1997-01-03 12:00:00
#
# ...
